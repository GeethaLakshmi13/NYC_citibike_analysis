# %% [markdown]
# # 01 Import Library

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Import Data

# %%
#folder shortcut
path = r'C:\Users\Admin\Documents\CF Tasks\Python Advanced Analytics'

# %%
#import citibike csv
citi61 = pd.read_csv(os.path.join(path, '02 Data','prepared data', 'citi_61.csv'), index_col = False)

# %% [markdown]
# # 03 Data Cleaning and Wrangling

# %%
citi61.head()
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22               521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 4  2013-09-07 18:46:38             476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  trip_duration      subscriber  \
# 0             40.742388             -73.997262            993      Subscriber
# 1             40.728419             -73.987140            581      Subscriber
# 2             40.768254             -73.988639            361      Subscriber
# 3             40.756014             -73.967416            561      Subscriber
# 4             40.743943             -73.979661           2296  Non-Subscriber
#
#    birth_year  gender
# 0      1968.0       2
# 1      1983.0       1
# 2      1989.0       1
# 3      1988.0       2
# 4         NaN       0

# %%
#checking nulls again
citi61.isnull().sum()
# Out:
# trip_id                       0
# bike_id                       0
# weekday                       0
# start_hour                    0
# start_time                    0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_time                      0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# trip_duration                 0
# subscriber                    0
# birth_year                 6979
# gender                        0
# dtype: int64

# %%
#making a subset of nan values in year of. birth
nan_birth = citi61[citi61['birth_year'].isnull() ==True]

# %%
nan_birth.shape
# Out:
# (6979, 18)

# %%
#dropping Nan Values
citi_clean = citi61[citi61['birth_year'].isnull()== False]

# %%
#checking on successful drop
citi_clean.shape
# Out:
# (43021, 18)

# %%
citi_clean.head()
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 5  HbKJBz    14581     Fri          22  2013-09-27 22:01:01               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 5    Lafayette St & E 8 St               40.730287               -73.990765
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 5  2013-09-27 22:08:08             432    E 7 St & Avenue A
#
#    end_station_latitude  end_station_longitude  trip_duration  subscriber  \
# 0             40.742388             -73.997262            993  Subscriber
# 1             40.728419             -73.987140            581  Subscriber
# 2             40.768254             -73.988639            361  Subscriber
# 3             40.756014             -73.967416            561  Subscriber
# 5             40.726218             -73.983799            427  Subscriber
#
#    birth_year  gender
# 0      1968.0       2
# 1      1983.0       1
# 2      1989.0       1
# 3      1988.0       2
# 5      1986.0       2

# %%
# dropping unnessesary columns
citi_clean = citi_clean.drop(columns = ['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 # dropping unnessesary columns
# ----> 2 citi_clean = citi_clean.drop(columns = ['Unnamed: 0'])
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
citi_clean = citi_clean.drop(columns = ['trip_id'])

# %%
citi_clean = citi_clean.drop(columns = ['bike_id'])

# %%
citi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43021 entries, 0 to 49999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  43021 non-null  object
#  1   weekday                  43021 non-null  object
#  2   start_hour               43021 non-null  int64
#  3   start_time               43021 non-null  object
#  4   start_station_id         43021 non-null  int64
#  5   start_station_name       43021 non-null  object
#  6   start_station_latitude   43021 non-null  float64
#  7   start_station_longitude  43021 non-null  float64
#  8   end_time                 43021 non-null  object
#  9   end_station_id           43021 non-null  int64
#  10  end_station_name         43021 non-null  object
#  11  end_station_latitude     43021 non-null  float64
#  12  end_station_longitude    43021 non-null  float64
#  13  trip_duration            43021 non-null  int64
#  14  subscriber               43021 non-null  object
#  15  birth_year               43021 non-null  float64
#  16  gender                   43021 non-null  int64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 5.9+ MB

# %%
#making a subset of users born after 1922
citi_clean_1 = citi_clean.loc[citi_clean['birth_year'] > 1922]

# %%
citi_clean.shape
# Out:
# (43021, 17)

# %%
citi_clean_1.shape
# Out:
# (42993, 17)

# %%
citi_clean_1.head()
# Out:
#   trip_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt     Sat          11  2013-09-28 11:54:37               527
# 5  HbKJBz     Fri          22  2013-09-27 22:01:01               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 5    Lafayette St & E 8 St               40.730287               -73.990765
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 5  2013-09-27 22:08:08             432    E 7 St & Avenue A
#
#    end_station_latitude  end_station_longitude  trip_duration  subscriber  \
# 0             40.742388             -73.997262            993  Subscriber
# 1             40.728419             -73.987140            581  Subscriber
# 2             40.768254             -73.988639            361  Subscriber
# 3             40.756014             -73.967416            561  Subscriber
# 5             40.726218             -73.983799            427  Subscriber
#
#    birth_year  gender
# 0      1968.0       2
# 1      1983.0       1
# 2      1989.0       1
# 3      1988.0       2
# 5      1986.0       2

# %%
# making sure there are 7 days of the week
citi_clean_1['day_of_week'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day_of_week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 # making sure there are 7 days of the week
# ----> 2 citi_clean_1['day_of_week'].unique()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'day_of_week'

# %%
#changing gender type to string
citi_clean_1['gender'] = citi_clean_1['gender'].astype('str')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5036\57663948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citi_clean_1['gender'] = citi_clean_1['gender'].astype('str')

# %%
#changing gender variables to the name of gender
citi_clean_1['gender']=citi_clean_1['gender'].replace([0,1,2],['Uknown','male','female'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5036\1073730475.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citi_clean_1['gender']=citi_clean_1['gender'].replace([0,1,2],['Uknown','male','female'])

# %%
citi_clean_1.describe()
# Out:
#          start_hour  start_station_id  start_station_latitude  \
# count  42993.000000      42993.000000            42993.000000
# mean      14.085316        437.205545               40.734477
# std        4.932889        340.848654                0.019598
# min        0.000000         72.000000               40.680342
# 25%       10.000000        304.000000               40.721101
# 50%       15.000000        402.000000               40.736245
# 75%       18.000000        485.000000               40.749718
# max       23.000000       3002.000000               40.770513
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             42993.000000    42993.000000          42993.000000
# mean                -73.990948      434.577094             40.734070
# std                   0.012367      332.801118              0.019603
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.000040      305.000000             40.720828
# 50%                 -73.990765      402.000000             40.735877
# 75%                 -73.981948      483.000000             40.749013
# max                 -73.950048     3002.000000             40.770513
#
#        end_station_longitude  trip_duration    birth_year
# count           42993.000000   42993.000000  42993.000000
# mean              -73.991242     770.502105   1975.674459
# std                 0.012375     523.444233     10.938735
# min               -74.017134      60.000000   1924.000000
# 25%               -74.000271     395.000000   1968.000000
# 50%               -73.990985     621.000000   1978.000000
# 75%               -73.982578     999.000000   1984.000000
# max               -73.950048    2697.000000   1997.000000

# %%
citi_clean_1.head()
# Out:
#   trip_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt     Sat          11  2013-09-28 11:54:37               527
# 5  HbKJBz     Fri          22  2013-09-27 22:01:01               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 5    Lafayette St & E 8 St               40.730287               -73.990765
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 5  2013-09-27 22:08:08             432    E 7 St & Avenue A
#
#    end_station_latitude  end_station_longitude  trip_duration  subscriber  \
# 0             40.742388             -73.997262            993  Subscriber
# 1             40.728419             -73.987140            581  Subscriber
# 2             40.768254             -73.988639            361  Subscriber
# 3             40.756014             -73.967416            561  Subscriber
# 5             40.726218             -73.983799            427  Subscriber
#
#    birth_year gender
# 0      1968.0      2
# 1      1983.0      1
# 2      1989.0      1
# 3      1988.0      2
# 5      1986.0      2

# %%
#changing start time to start of ride and making the datatype - datetime
citi_clean_1['start_of_ride']=pd.to_datetime(citi_clean_1['start_time'],infer_datetime_format=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5036\3511997610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citi_clean_1['start_of_ride']=pd.to_datetime(citi_clean_1['start_time'],infer_datetime_format=True)

# %%
#checking code
citi_clean_1.head()
# Out:
#   trip_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt     Sat          11  2013-09-28 11:54:37               527
# 5  HbKJBz     Fri          22  2013-09-27 22:01:01               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 5    Lafayette St & E 8 St               40.730287               -73.990765
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 5  2013-09-27 22:08:08             432    E 7 St & Avenue A
#
#    end_station_latitude  end_station_longitude  trip_duration  subscriber  \
# 0             40.742388             -73.997262            993  Subscriber
# 1             40.728419             -73.987140            581  Subscriber
# 2             40.768254             -73.988639            361  Subscriber
# 3             40.756014             -73.967416            561  Subscriber
# 5             40.726218             -73.983799            427  Subscriber
#
#    birth_year gender       start_of_ride
# 0      1968.0      2 2013-09-09 18:18:55
# 1      1983.0      1 2013-09-12 18:38:53
# 2      1989.0      1 2013-09-18 19:44:04
# 3      1988.0      2 2013-09-28 11:54:37
# 5      1986.0      2 2013-09-27 22:01:01

# %%
#checking data type
citi_clean_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42993 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  42993 non-null  object
#  1   weekday                  42993 non-null  object
#  2   start_hour               42993 non-null  int64
#  3   start_time               42993 non-null  object
#  4   start_station_id         42993 non-null  int64
#  5   start_station_name       42993 non-null  object
#  6   start_station_latitude   42993 non-null  float64
#  7   start_station_longitude  42993 non-null  float64
#  8   end_time                 42993 non-null  object
#  9   end_station_id           42993 non-null  int64
#  10  end_station_name         42993 non-null  object
#  11  end_station_latitude     42993 non-null  float64
#  12  end_station_longitude    42993 non-null  float64
#  13  trip_duration            42993 non-null  int64
#  14  subscriber               42993 non-null  object
#  15  birth_year               42993 non-null  float64
#  16  gender                   42993 non-null  object
#  17  start_of_ride            42993 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(4), object(8)
# memory usage: 6.2+ MB

# %%
#changing end time to end of ride and making the datatype - datetime
citi_clean_1['end_of_ride']=pd.to_datetime(citi_clean_1['end_time'],infer_datetime_format=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5036\2350848099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citi_clean_1['end_of_ride']=pd.to_datetime(citi_clean_1['end_time'],infer_datetime_format=True)

# %%
#checking code
citi_clean_1.head()
# Out:
#   trip_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt     Sat          11  2013-09-28 11:54:37               527
# 5  HbKJBz     Fri          22  2013-09-27 22:01:01               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 5    Lafayette St & E 8 St               40.730287               -73.990765
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 5  2013-09-27 22:08:08             432    E 7 St & Avenue A
#
#    end_station_latitude  end_station_longitude  trip_duration  subscriber  \
# 0             40.742388             -73.997262            993  Subscriber
# 1             40.728419             -73.987140            581  Subscriber
# 2             40.768254             -73.988639            361  Subscriber
# 3             40.756014             -73.967416            561  Subscriber
# 5             40.726218             -73.983799            427  Subscriber
#
#    birth_year gender       start_of_ride         end_of_ride
# 0      1968.0      2 2013-09-09 18:18:55 2013-09-09 18:35:28
# 1      1983.0      1 2013-09-12 18:38:53 2013-09-12 18:48:34
# 2      1989.0      1 2013-09-18 19:44:04 2013-09-18 19:50:05
# 3      1988.0      2 2013-09-28 11:54:37 2013-09-28 12:03:58
# 5      1986.0      2 2013-09-27 22:01:01 2013-09-27 22:08:08

# %%
#checking data type
citi_clean_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42993 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  42993 non-null  object
#  1   weekday                  42993 non-null  object
#  2   start_hour               42993 non-null  int64
#  3   start_time               42993 non-null  object
#  4   start_station_id         42993 non-null  int64
#  5   start_station_name       42993 non-null  object
#  6   start_station_latitude   42993 non-null  float64
#  7   start_station_longitude  42993 non-null  float64
#  8   end_time                 42993 non-null  object
#  9   end_station_id           42993 non-null  int64
#  10  end_station_name         42993 non-null  object
#  11  end_station_latitude     42993 non-null  float64
#  12  end_station_longitude    42993 non-null  float64
#  13  trip_duration            42993 non-null  int64
#  14  subscriber               42993 non-null  object
#  15  birth_year               42993 non-null  float64
#  16  gender                   42993 non-null  object
#  17  start_of_ride            42993 non-null  datetime64[ns]
#  18  end_of_ride              42993 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(4), object(8)
# memory usage: 6.6+ MB

# %%
#dropping start time column
citi_clean_1 = citi_clean_1.drop(columns = ['start_time'])

# %%
#dropping end time column
citi_clean_1 = citi_clean_1.drop(columns = ['end_time'])

# %%
citi_clean_1.head()
# Out:
#   trip_id weekday  start_hour  start_station_id       start_station_name  \
# 0  LnQzQk     Mon          18               523          W 38 St & 8 Ave
# 1  IL9boN     Thu          18               257  Lispenard St & Broadway
# 2  46clGB     Wed          19               479          9 Ave & W 45 St
# 3  v7vdFt     Sat          11               527          E 33 St & 1 Ave
# 5  HbKJBz     Fri          22               293    Lafayette St & E 8 St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               40.754666               -73.991382             334
# 1               40.719392               -74.002472             236
# 2               40.760193               -73.991255             513
# 3               40.743156               -73.974347             441
# 5               40.730287               -73.990765             432
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 5    E 7 St & Avenue A             40.726218             -73.983799
#
#    trip_duration  subscriber  birth_year gender       start_of_ride  \
# 0            993  Subscriber      1968.0      2 2013-09-09 18:18:55
# 1            581  Subscriber      1983.0      1 2013-09-12 18:38:53
# 2            361  Subscriber      1989.0      1 2013-09-18 19:44:04
# 3            561  Subscriber      1988.0      2 2013-09-28 11:54:37
# 5            427  Subscriber      1986.0      2 2013-09-27 22:01:01
#
#           end_of_ride
# 0 2013-09-09 18:35:28
# 1 2013-09-12 18:48:34
# 2 2013-09-18 19:50:05
# 3 2013-09-28 12:03:58
# 5 2013-09-27 22:08:08

# %% [markdown]
# # 04 Saving and Exporting DF

# %%
#13 saving and exporting DF
citi_clean_1.to_csv(os.path.join(path, '02 Data','prepared data', 'cleaned_citi_61.csv'))
